# %% [markdown]
# Il faudrait voir à pouvoir mettre le vaccin à un certain moment t et pas dès le départ
#
# Taux d'immunité pour les R d'environ 6 mois/ 1 an avant de pouvoir être réinfecté
# Les vaccinés ont une proba non nul $\beta '$ d'être infecté
#
# Zombie : Grille fixe avec des règles intercases ou Un individu se déplace avec un rayon max où il voit une autre personne
# Transformée de fourier
# Equation spatiale avec discrétisation du système, gradient de chaleur (opérateur laplacien)
